# %%
# gta 영상으로 테스트
from IPython.display import Image
import os

# !python /content/yolov5/detect.py --weights /content/yolov5/best.pt --img 416 --conf 0.5 --source /content/gta5test.mp4

# %%
# gta 사진으로 테스트
from IPython.display import Image
import os

# !python /content/yolov5/val.py --weights /content/yolov5/best.pt --img 416 --batch 32 --data /content/data.yaml --task 'test' --iou-thres 0.1
# Out:
# val: data=/content/data.yaml, weights=['/content/yolov5/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.001, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-227-ga6e99e4 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning '/content/test/labels.cache' images and labels... 60 found, 0 missing, 0 empty, 0 corrupt: 100% 60/60 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:01<00:00,  1.32it/s]
#                  all         60        271      0.246      0.126      0.162       0.11
#                biker         60        197      0.733       0.32      0.483      0.327
# ...
